# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
data=[(1,'sai'),(2,'pranay'),(3,'Nandu')]
df=spark.createDataFrame(data,['id','name'])
df.show()
# Out:
# +---+------+
# | id|  name|
# +---+------+
# |  1|   sai|
# |  2|pranay|
# |  3| Nandu|
# +---+------+

# %%
df = spark.table('dbw_de_training.default.housing')
df.display(5)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.printSchema()
df.describe().show()
# Out:
# root
#  |-- price: long (nullable = true)
#  |-- area: long (nullable = true)
#  |-- bedrooms: long (nullable = true)
#  |-- bathrooms: long (nullable = true)
#  |-- stories: long (nullable = true)
#  |-- mainroad: string (nullable = true)
#  |-- guestroom: string (nullable = true)
#  |-- basement: string (nullable = true)
#  |-- hotwaterheating: string (nullable = true)
#  |-- airconditioning: string (nullable = true)
#  |-- parking: long (nullable = true)
#  |-- prefarea: string (nullable = true)
#  |-- furnishingstatus: string (nullable = true)
#
# +-------+-----------------+-----------------+------------------+------------------+------------------+--------+---------+--------+---------------+---------------+------------------+--------+----------------+
# |summary|            price|             area|          bedrooms|         bathrooms|           stories|mainroad|guestroom|basement|hotwaterheating|airconditioning|           parking|prefarea|furnishingstatus|
# ...

# %%
df.select('price','area').show(5)
df.filter(df.area>7000).show(5)
# Out:
# +--------+----+
# |   price|area|
# +--------+----+
# |13300000|7420|
# |12250000|8960|
# |12250000|9960|
# |12215000|7500|
# |11410000|7420|
# +--------+----+
# only showing top 5 rows
# +--------+----+--------+---------+-------+--------+---------+--------+---------------+---------------+-------+--------+----------------+
# |   price|area|bedrooms|bathrooms|stories|mainroad|guestroom|basement|hotwaterheating|airconditioning|parking|prefarea|furnishingstatus|
# +--------+----+--------+---------+-------+--------+---------+--------+---------------+---------------+-------+--------+----------------+
# |13300000|7420|       4|        2|      3|     yes|       no|      no|             no|            yes|      2|     yes|       furnished|
# |12250000|8960|       4|        4|      4|     yes|       no|      no|             no|            yes|      3|      no|       furnished|
# ...

# %%
df.withColumn('doubled_area',col('area')*2).show(5)
# Out:
# +--------+----+--------+---------+-------+--------+---------+--------+---------------+---------------+-------+--------+----------------+------------+
# |   price|area|bedrooms|bathrooms|stories|mainroad|guestroom|basement|hotwaterheating|airconditioning|parking|prefarea|furnishingstatus|doubled_area|
# +--------+----+--------+---------+-------+--------+---------+--------+---------------+---------------+-------+--------+----------------+------------+
# |13300000|7420|       4|        2|      3|     yes|       no|      no|             no|            yes|      2|     yes|       furnished|       14840|
# |12250000|8960|       4|        4|      4|     yes|       no|      no|             no|            yes|      3|      no|       furnished|       17920|
# |12250000|9960|       3|        2|      2|     yes|       no|     yes|             no|             no|      2|     yes|  semi-furnished|       19920|
# ...

# %%
df.withColumn('area',col('area').cast('int'))
df.printSchema()
# Out:
# root
#  |-- price: long (nullable = true)
#  |-- area: long (nullable = true)
#  |-- bedrooms: long (nullable = true)
#  |-- bathrooms: long (nullable = true)
#  |-- stories: long (nullable = true)
#  |-- mainroad: string (nullable = true)
#  |-- guestroom: string (nullable = true)
#  |-- basement: string (nullable = true)
#  |-- hotwaterheating: string (nullable = true)
#  |-- airconditioning: string (nullable = true)
#  |-- parking: long (nullable = true)
#  |-- prefarea: string (nullable = true)
#  |-- furnishingstatus: string (nullable = true)
